# %%
import pandas as pd

# %%
df = pd.read_csv("student_history.csv", index_col="epoch")

# %%
df
# Out:
#             loss  val_loss            model
# epoch
# 1      69.293358  1.803686        Temp_0.05
# 1      65.454910  1.793591         Temp_0.1
# 1      72.330643  1.794897         Temp_0.5
# 1      66.755165  1.803636         Temp_1.5
# 1      57.398304  1.800219           Temp_1
# 1      65.921272  1.802038  Temp_sum_normal
# 2       1.799883  1.790558        Temp_0.05
# 2       1.795479  1.791006         Temp_0.1
# 2       1.794912  1.791888         Temp_0.5
# 2       1.794336  1.791782         Temp_1.5
# 2       1.793759  1.791779           Temp_1
# 2       1.795312  1.791319  Temp_sum_normal
# 3       1.791275  1.790770        Temp_0.05
# 3       1.790464  1.791072         Temp_0.1
# 3       1.791610  1.791699         Temp_0.5
# 3       1.791771  1.791768         Temp_1.5
# 3       1.791784  1.791777           Temp_1
# 3       1.791215  1.791279  Temp_sum_normal
# 4       1.788747  1.789993        Temp_0.05
# 4       1.789999  1.791627         Temp_0.1
# ...

# %%
import seaborn as sns
sns.lineplot(df, x='epoch', y='loss', hue='model')
# Out:
# d:\Projects\Agar.io\env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Projects\Agar.io\env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Projects\Agar.io\env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Projects\Agar.io\env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ...

# %%
groups = df.groupby('model')
len(groups)
# Out:
# 6

# %%
import matplotlib.pyplot as plt
for g in groups.groups.keys():
    plt.figure()
    sns.lineplot(groups.get_group(g), )
    plt.title(g)
# Out:
# d:\Projects\Agar.io\env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Projects\Agar.io\env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Projects\Agar.io\env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# d:\Projects\Agar.io\env\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# ...
